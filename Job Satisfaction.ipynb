# %% [markdown]
# #### Job Satisfaction
#
# In this notebook, you will be exploring job satisfaction according to the survey results.  Use the cells at the top of the notebook to explore as necessary, and use your findings to solve the questions at the bottom of the notebook.

# %%
import pandas as pd
import numpy as np
import JobSatisfaction as t
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('./survey_results_public.csv')
schema = pd.read_csv('./survey_results_schema.csv')
df.columns
df.head(10)
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
# 5           6                                            Student
# 6           7  Professional non-developer who sometimes write...
# 7           8                             Professional developer
# 8           9                             Professional developer
# 9          10                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
# 5                  Yes, both     New Zealand  Yes, full-time
# 6                  Yes, both   United States              No
# 7                  Yes, both          Poland              No
# 8  Yes, I program as a hobby        Colombia  Yes, part-time
# 9  Yes, I program as a hobby          France  Yes, full-time
#
#                                     EmploymentStatus  \
# 0             Not employed, and not looking for work
# 1                                 Employed part-time
# 2                                 Employed full-time
# 3                                 Employed full-time
# 4                                 Employed full-time
# 5             Not employed, and not looking for work
# 6                                 Employed full-time
# 7                                 Employed full-time
# 8                                 Employed full-time
# 9  Independent contractor, freelancer, or self-em...
#
#                                      FormalEducation  \
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
# 3                                    Doctoral degree
# 4                                    Master's degree
# 5                                   Secondary school
# 6                                    Master's degree
# 7                                    Master's degree
# 8                                  Bachelor's degree
# 9                                    Master's degree
#
#                                   MajorUndergrad  \
# 0                                            NaN
# 1       Computer science or software engineering
# 2       Computer science or software engineering
# 3  A non-computer-focused engineering discipline
# 4       Computer science or software engineering
# 5                                            NaN
# 6  A non-computer-focused engineering discipline
# 7       Computer science or software engineering
# 8       Computer science or software engineering
# 9       Computer science or software engineering
#
#                                           HomeRemote  \
# 0                                                NaN
# 1              More than half, but not all, the time
# 2  Less than half the time, but at least one day ...
# 3  Less than half the time, but at least one day ...
# 4                                              Never
# 5                                                NaN
# 6  Less than half the time, but at least one day ...
# 7  All or almost all the time (I'm full-time remote)
# 8  Less than half the time, but at least one day ...
# 9                                   It's complicated
#
#                 CompanySize       ...       StackOverflowMakeMoney Gender  \
# 0                       NaN       ...            Strongly disagree   Male
# 1        20 to 99 employees       ...            Strongly disagree   Male
# 2  10,000 or more employees       ...                     Disagree   Male
# 3  10,000 or more employees       ...                     Disagree   Male
# 4        10 to 19 employees       ...                          NaN    NaN
# 5                       NaN       ...                     Disagree    NaN
# 6        20 to 99 employees       ...                     Disagree   Male
# 7   Fewer than 10 employees       ...               Somewhat agree   Male
# 8  5,000 to 9,999 employees       ...            Strongly disagree   Male
# 9                       NaN       ...                     Disagree   Male
#
#   HighestEducationParents                          Race         SurveyLong  \
# 0             High school  White or of European descent  Strongly disagree
# 1       A master's degree  White or of European descent     Somewhat agree
# 2   A professional degree  White or of European descent     Somewhat agree
# 3       A doctoral degree  White or of European descent              Agree
# 4                     NaN                           NaN                NaN
# 5     A bachelor's degree  White or of European descent           Disagree
# 6       A doctoral degree  White or of European descent           Disagree
# 7       A master's degree  White or of European descent              Agree
# 8     A bachelor's degree     Hispanic or Latino/Latina     Somewhat agree
# 9       A doctoral degree  White or of European descent     Somewhat agree
#
#   QuestionsInteresting QuestionsConfusing InterestedAnswers    Salary  \
# 0       Strongly agree           Disagree    Strongly agree       NaN
# 1       Somewhat agree           Disagree    Strongly agree       NaN
# 2                Agree           Disagree             Agree  113750.0
# 3                Agree     Somewhat agree    Strongly agree       NaN
# 4                  NaN                NaN               NaN       NaN
# 5                Agree           Disagree             Agree       NaN
# 6                Agree           Disagree             Agree       NaN
# 7       Somewhat agree           Disagree             Agree       NaN
# 8       Strongly agree           Disagree    Strongly agree       NaN
# 9                Agree           Disagree             Agree       NaN
#
#    ExpectedSalary
# 0             NaN
# 1         37500.0
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
#
# [10 rows x 154 columns]

# %%
list(df) #Space for your code
# Out:
# ['Respondent',
#  'Professional',
#  'ProgramHobby',
#  'Country',
#  'University',
#  'EmploymentStatus',
#  'FormalEducation',
#  'MajorUndergrad',
#  'HomeRemote',
#  'CompanySize',
#  'CompanyType',
#  'YearsProgram',
#  'YearsCodedJob',
#  'YearsCodedJobPast',
#  'DeveloperType',
#  'WebDeveloperType',
#  'MobileDeveloperType',
#  'NonDeveloperType',
#  'CareerSatisfaction',
#  'JobSatisfaction',
#  'ExCoderReturn',
#  'ExCoderNotForMe',
#  'ExCoderBalance',
#  'ExCoder10Years',
#  'ExCoderBelonged',
#  'ExCoderSkills',
#  'ExCoderWillNotCode',
#  'ExCoderActive',
#  'PronounceGIF',
#  'ProblemSolving',
#  'BuildingThings',
#  'LearningNewTech',
#  'BoringDetails',
#  'JobSecurity',
#  'DiversityImportant',
#  'AnnoyingUI',
#  'FriendsDevelopers',
#  'RightWrongWay',
#  'UnderstandComputers',
#  'SeriousWork',
#  'InvestTimeTools',
#  'WorkPayCare',
#  'KinshipDevelopers',
#  'ChallengeMyself',
#  'CompetePeers',
#  'ChangeWorld',
#  'JobSeekingStatus',
#  'HoursPerWeek',
#  'LastNewJob',
#  'AssessJobIndustry',
#  'AssessJobRole',
#  'AssessJobExp',
#  'AssessJobDept',
#  'AssessJobTech',
#  'AssessJobProjects',
#  'AssessJobCompensation',
#  'AssessJobOffice',
#  'AssessJobCommute',
#  'AssessJobRemote',
#  'AssessJobLeaders',
#  'AssessJobProfDevel',
#  'AssessJobDiversity',
#  'AssessJobProduct',
#  'AssessJobFinances',
#  'ImportantBenefits',
#  'ClickyKeys',
#  'JobProfile',
#  'ResumePrompted',
#  'LearnedHiring',
#  'ImportantHiringAlgorithms',
#  'ImportantHiringTechExp',
#  'ImportantHiringCommunication',
#  'ImportantHiringOpenSource',
#  'ImportantHiringPMExp',
#  'ImportantHiringCompanies',
#  'ImportantHiringTitles',
#  'ImportantHiringEducation',
#  'ImportantHiringRep',
#  'ImportantHiringGettingThingsDone',
#  'Currency',
#  'Overpaid',
#  'TabsSpaces',
#  'EducationImportant',
#  'EducationTypes',
#  'SelfTaughtTypes',
#  'TimeAfterBootcamp',
#  'CousinEducation',
#  'WorkStart',
#  'HaveWorkedLanguage',
#  'WantWorkLanguage',
#  'HaveWorkedFramework',
#  'WantWorkFramework',
#  'HaveWorkedDatabase',
#  'WantWorkDatabase',
#  'HaveWorkedPlatform',
#  'WantWorkPlatform',
#  'IDE',
#  'AuditoryEnvironment',
#  'Methodology',
#  'VersionControl',
#  'CheckInCode',
#  'ShipIt',
#  'OtherPeoplesCode',
#  'ProjectManagement',
#  'EnjoyDebugging',
#  'InTheZone',
#  'DifficultCommunication',
#  'CollaborateRemote',
#  'MetricAssess',
#  'EquipmentSatisfiedMonitors',
#  'EquipmentSatisfiedCPU',
#  'EquipmentSatisfiedRAM',
#  'EquipmentSatisfiedStorage',
#  'EquipmentSatisfiedRW',
#  'InfluenceInternet',
#  'InfluenceWorkstation',
#  'InfluenceHardware',
#  'InfluenceServers',
#  'InfluenceTechStack',
#  'InfluenceDeptTech',
#  'InfluenceVizTools',
#  'InfluenceDatabase',
#  'InfluenceCloud',
#  'InfluenceConsultants',
#  'InfluenceRecruitment',
#  'InfluenceCommunication',
#  'StackOverflowDescribes',
#  'StackOverflowSatisfaction',
#  'StackOverflowDevices',
#  'StackOverflowFoundAnswer',
#  'StackOverflowCopiedCode',
#  'StackOverflowJobListing',
#  'StackOverflowCompanyPage',
#  'StackOverflowJobSearch',
#  'StackOverflowNewQuestion',
#  'StackOverflowAnswer',
#  'StackOverflowMetaChat',
#  'StackOverflowAdsRelevant',
#  'StackOverflowAdsDistracting',
#  'StackOverflowModeration',
#  'StackOverflowCommunity',
#  'StackOverflowHelpful',
#  'StackOverflowBetter',
#  'StackOverflowWhatDo',
#  'StackOverflowMakeMoney',
#  'Gender',
#  'HighestEducationParents',
#  'Race',
#  'SurveyLong',
#  'QuestionsInteresting',
#  'QuestionsConfusing',
#  'InterestedAnswers',
#  'Salary',
#  'ExpectedSalary']

# %%
Job_df = df["JobSatisfaction"].value_counts(normalize= False)#More space for code
Job_df
# Out:
# 8.0     3483
# 7.0     3087
# 9.0     2159
# 6.0     1749
# 10.0    1529
# 5.0     1370
# 4.0      668
# 3.0      598
# 2.0      322
# 0.0      154
# 1.0      134
# Name: JobSatisfaction, dtype: int64

# %%
Job2_df = df["JobSatisfaction"].isnull().mean()
Job2_df
# Out:
# 0.20149722542142184

# %%
Status_df = df["EmploymentStatus"].value_counts(normalize= False)
Status_df #Additional space for your additional code
# Out:
# Employed full-time                                      13655
# Independent contractor, freelancer, or self-employed     1866
# Employed part-time                                       1168
# Not employed, and not looking for work                   1066
# Not employed, but looking for work                        906
# I prefer not to say                                       381
# Retired                                                    60
# Name: EmploymentStatus, dtype: int64

# %%
#Feel free to create new cells as you need them
# Out:
# EmploymentStatus
# Not employed, and not looking for work                 NaN
# Employed part-time                                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Not employed, and not looking for work                 NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Independent contractor, freelancer, or self-employed   NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Not employed, but looking for work                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Independent contractor, freelancer, or self-employed   NaN
# Not employed, and not looking for work                 NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Independent contractor, freelancer, or self-employed   NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
#                                                         ..
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Independent contractor, freelancer, or self-employed   NaN
# Employed part-time                                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Independent contractor, freelancer, or self-employed   NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Employed part-time                                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Independent contractor, freelancer, or self-employed   NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Independent contractor, freelancer, or self-employed   NaN
# Independent contractor, freelancer, or self-employed   NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Not employed, and not looking for work                 NaN
# Independent contractor, freelancer, or self-employed   NaN
# Employed full-time                                     NaN
# Employed full-time                                     NaN
# Name: JobSatisfaction, Length: 19102, dtype: float64

# %%
df.groupby(['EmploymentStatus']).mean()['JobSatisfaction'].sort_values()
# Out:
# EmploymentStatus
# Employed part-time                                      6.846154
# Employed full-time                                      6.980608
# Independent contractor, freelancer, or self-employed    7.231985
# I prefer not to say                                          NaN
# Not employed, and not looking for work                       NaN
# Not employed, but looking for work                           NaN
# Retired                                                      NaN
# Name: JobSatisfaction, dtype: float64

# %%
df.groupby(["CompanySize"]).mean()['JobSatisfaction'].sort_values()
# Out:
# CompanySize
# 10,000 or more employees    6.793617
# 5,000 to 9,999 employees    6.832155
# 1,000 to 4,999 employees    6.908506
# 20 to 99 employees          6.997039
# Fewer than 10 employees     7.025719
# 100 to 499 employees        7.029324
# 500 to 999 employees        7.029967
# 10 to 19 employees          7.035739
# I don't know                7.054622
# I prefer not to answer      7.284946
# Name: JobSatisfaction, dtype: float64

# %% [markdown]
# #### Question 1
#
# **1.** Use the space above to assist in matching each variable (**a**, **b**, **c**, **d**, **e**, **f**, **g**, or **h** ) as the appropriate key that describes the value in the **job_sol_1** dictionary.

# %%
a = 0.734
b = 0.2014
c = 'full-time'
d = 'contractors'
e = 'retired'
f = 'yes'
g = 'no'
h = 'hard to tell'

job_sol_1 = {'The proportion of missing values in the Job Satisfaction column':b ,
             'According to EmploymentStatus, which group has the highest average job satisfaction?':c , 
             'In general, do smaller companies appear to have employees with higher job satisfaction?': f}
             
t.jobsat_check1(job_sol_1)
# Out:
# Oops! Though it wasn't what I was expecting either, the job category with the highest job satisfaction was not fulltime nor retired individuals!

# %%
df.groupby(["ProgramHobby"]).mean()["JobSatisfaction"]
# Out:
# ProgramHobby
# No                                           6.874806
# Yes, I contribute to open source projects    7.158649
# Yes, I program as a hobby                    6.927150
# Yes, both                                    7.189316
# Name: JobSatisfaction, dtype: float64

# %%
df.groupby(["HomeRemote"]).mean()["JobSatisfaction"].sort_values()
# Out:
# HomeRemote
# Never                                                      6.697127
# It's complicated                                           6.942053
# More than half, but not all, the time                      6.973684
# A few days each month                                      7.096694
# About half the time                                        7.125737
# Less than half the time, but at least one day each week    7.143786
# All or almost all the time (I'm full-time remote)          7.405421
# Name: JobSatisfaction, dtype: float64

# %%
df.groupby(["FormalEducation"]).mean()["JobSatisfaction"].sort_values()
# Out:
# FormalEducation
# Bachelor's degree                                                    6.900293
# Primary/elementary school                                            6.946237
# Master's degree                                                      6.977356
# I never completed any formal education                               7.000000
# Professional degree                                                  7.075893
# Some college/university study without earning a bachelor's degree    7.151268
# I prefer not to answer                                               7.211679
# Secondary school                                                     7.219512
# Doctoral degree                                                      7.438492
# Name: JobSatisfaction, dtype: float64

# %%
df.groupby(["FormalEducation"]).mean()["Salary"].sort_values()
# Out:
# FormalEducation
# I prefer not to answer                                               35191.954323
# Secondary school                                                     38813.163348
# I never completed any formal education                               46337.639391
# Professional degree                                                  48176.450790
# Some college/university study without earning a bachelor's degree    58979.808989
# Bachelor's degree                                                    59004.115834
# Master's degree                                                      60398.444414
# Primary/elementary school                                            65152.544305
# Doctoral degree                                                      78174.121389
# Name: Salary, dtype: float64

# %% [markdown]
# #### Question 2
#
# **2.** Use the space above to assist in matching each variable (**a**, **b**, **c** ) as the appropriate key that describes the value in the **job_sol_2** dictionary. Notice you can have the same letter appear more than once.

# %%
a = 'yes'
b = 'no'
c = 'hard to tell'

job_sol_2 = {'Do individuals who program outside of work appear to have higher JobSatisfaction?': a ,
             'Does flexibility to work outside of the office appear to have an influence on JobSatisfaction?': a, 
             'A friend says a Doctoral degree increases the chance of having job you like, does this seem true?': a}
             
t.jobsat_check2(job_sol_2)
# Out:
# Nice job! That's what we found as well!

# %%
df.groupby(["FormalEducation"]).mean()
# Out:
#                                                       Respondent  \
# FormalEducation
# Bachelor's degree                                    9527.091616
# Doctoral degree                                      9627.894737
# I never completed any formal education               9803.351724
# I prefer not to answer                              10269.017115
# Master's degree                                      9582.720492
# Primary/elementary school                            9297.061881
# Professional degree                                 10387.180392
# Secondary school                                     9746.805568
# Some college/university study without earning a...   9255.581387
#
#                                                     CareerSatisfaction  \
# FormalEducation
# Bachelor's degree                                             7.322164
# Doctoral degree                                               7.574349
# I never completed any formal education                        7.196581
# I prefer not to answer                                        7.338542
# Master's degree                                               7.300302
# Primary/elementary school                                     7.406897
# Professional degree                                           7.465812
# Secondary school                                              7.348285
# Some college/university study without earning a...            7.424099
#
#                                                     JobSatisfaction  \
# FormalEducation
# Bachelor's degree                                          6.900293
# Doctoral degree                                            7.438492
# I never completed any formal education                     7.000000
# I prefer not to answer                                     7.211679
# Master's degree                                            6.977356
# Primary/elementary school                                  6.946237
# Professional degree                                        7.075893
# Secondary school                                           7.219512
# Some college/university study without earning a...         7.151268
#
#                                                     HoursPerWeek  \
# FormalEducation
# Bachelor's degree                                       4.104258
# Doctoral degree                                         3.067633
# I never completed any formal education                  6.893617
# I prefer not to answer                                  5.360000
# Master's degree                                         3.445985
# Primary/elementary school                               2.469388
# Professional degree                                     3.559633
# Secondary school                                        3.267901
# Some college/university study without earning a...      3.086491
#
#                                                     StackOverflowSatisfaction  \
# FormalEducation
# Bachelor's degree                                                    8.403451
# Doctoral degree                                                      8.242925
# I never completed any formal education                               8.125000
# I prefer not to answer                                               8.134715
# Master's degree                                                      8.355225
# Primary/elementary school                                            8.205240
# Professional degree                                                  8.337662
# Secondary school                                                     8.345531
# Some college/university study without earning a...                   8.312830
#
#                                                           Salary  \
# FormalEducation
# Bachelor's degree                                   59004.115834
# Doctoral degree                                     78174.121389
# I never completed any formal education              46337.639391
# I prefer not to answer                              35191.954323
# Master's degree                                     60398.444414
# Primary/elementary school                           65152.544305
# Professional degree                                 48176.450790
# Secondary school                                    38813.163348
# Some college/university study without earning a...  58979.808989
#
#                                                     ExpectedSalary
# FormalEducation
# Bachelor's degree                                     27459.337572
# Doctoral degree                                                NaN
# I never completed any formal education                67394.043949
# I prefer not to answer                                28040.986624
# Master's degree                                       27240.384932
# Primary/elementary school                             37274.890612
# Professional degree                                   15259.524758
# Secondary school                                      33031.294772
# Some college/university study without earning a...    35941.941020

# %%
df.groupby(["Professional"]).mean()
# Out:
#                                                       Respondent  \
# Professional
# None of these                                        9205.668478
# Professional developer                               9389.497749
# Professional non-developer who sometimes writes...  10155.910774
# Student                                              9962.575328
# Used to be a professional developer                  9893.184874
#
#                                                     CareerSatisfaction  \
# Professional
# None of these                                                 6.205797
# Professional developer                                        7.454832
# Professional non-developer who sometimes writes...            6.796128
# Student                                                       6.000000
# Used to be a professional developer                           6.899713
#
#                                                     JobSatisfaction  \
# Professional
# None of these                                                   NaN
# Professional developer                                     7.048795
# Professional non-developer who sometimes writes...         6.666872
# Student                                                         NaN
# Used to be a professional developer                        6.625000
#
#                                                     HoursPerWeek  \
# Professional
# None of these                                           4.852174
# Professional developer                                  3.484288
# Professional non-developer who sometimes writes...      3.747911
# Student                                                 4.397059
# Used to be a professional developer                     5.478571
#
#                                                     StackOverflowSatisfaction  \
# Professional
# None of these                                                        8.106667
# Professional developer                                               8.407563
# Professional non-developer who sometimes writes...                   8.210526
# Student                                                              8.268902
# Used to be a professional developer                                  7.786290
#
#                                                           Salary  \
# Professional
# None of these                                                NaN
# Professional developer                              58341.398571
# Professional non-developer who sometimes writes...           NaN
# Student                                                      NaN
# Used to be a professional developer                          NaN
#
#                                                     ExpectedSalary
# Professional
# None of these                                                  NaN
# Professional developer                                         NaN
# Professional non-developer who sometimes writes...             NaN
# Student                                               32231.521687
# Used to be a professional developer                            NaN
